# %% [markdown]
# # Visualizing trees built using sklearn

# %% [markdown]
# ## Import packages

# %%
from sklearn.datasets import load_wine, fetch_california_housing
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree, DecisionTreeClassifier, DecisionTreeRegressor

# %% [markdown]
# ## Classification model

# %%
# load wine data set
data = load_wine()
x = data.data
y = data.target

# split into train and test data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=42)

# create a decision tree classifier
clf = DecisionTreeClassifier(max_depth=2, random_state=0)
clf.fit(x_train, y_train)

# plot classifier tree
plt.figure(figsize=(10,8))
plot_tree(clf, feature_names=data.feature_names, class_names=data.target_names, filled=True)
# Out:
# [Text(279.0, 362.4, 'color_intensity <= 3.82\ngini = 0.658\nsamples = 124\nvalue = [40, 50, 34]\nclass = class_1'),
#  Text(139.5, 217.44, 'proline <= 1010.0\ngini = 0.083\nsamples = 46\nvalue = [2, 44, 0]\nclass = class_1'),
#  Text(69.75, 72.47999999999996, 'gini = 0.043\nsamples = 45\nvalue = [1, 44, 0]\nclass = class_1'),
#  Text(209.25, 72.47999999999996, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]\nclass = class_0'),
#  Text(418.5, 217.44, 'flavanoids <= 1.4\ngini = 0.567\nsamples = 78\nvalue = [38, 6, 34]\nclass = class_0'),
#  Text(348.75, 72.47999999999996, 'gini = 0.0\nsamples = 34\nvalue = [0, 0, 34]\nclass = class_2'),
#  Text(488.25, 72.47999999999996, 'gini = 0.236\nsamples = 44\nvalue = [38, 6, 0]\nclass = class_0')]

# %% [markdown]
# ## Regression model

# %%
# load data set
data = fetch_california_housing()
x = data.data
y = data.target

# split into train and test data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=42)

# create a decision tree regressor
clf = DecisionTreeRegressor(max_depth=2, random_state=0)
clf.fit(x_train, y_train)

# plot tree regressor
plt.figure(figsize=(10,8))
plot_tree(clf, feature_names=data.feature_names, filled=True)
# Out:
# [Text(279.0, 362.4, 'MedInc <= 5.032\nmse = 1.34\nsamples = 14448\nvalue = 2.069'),
#  Text(139.5, 217.44, 'MedInc <= 3.074\nmse = 0.835\nsamples = 11340\nvalue = 1.73'),
#  Text(69.75, 72.47999999999996, 'mse = 0.565\nsamples = 5490\nvalue = 1.356'),
#  Text(209.25, 72.47999999999996, 'mse = 0.833\nsamples = 5850\nvalue = 2.081'),
#  Text(418.5, 217.44, 'MedInc <= 6.868\nmse = 1.226\nsamples = 3108\nvalue = 3.308'),
#  Text(348.75, 72.47999999999996, 'mse = 0.904\nsamples = 2201\nvalue = 2.918'),
#  Text(488.25, 72.47999999999996, 'mse = 0.744\nsamples = 907\nvalue = 4.255')]
